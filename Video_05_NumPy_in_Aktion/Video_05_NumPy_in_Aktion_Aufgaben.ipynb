# %% [markdown]
# # Aufgaben zu Video 05: NumPy in Aktion

# %% [markdown]
# Bitte lösen Sie alle Aufgaben mit NumPy-Vektorisierung und vermeiden Sie es, mit Schleifen über Arrays zu iterieren.

# %% [markdown]
# ## Aufgabe 1
#
# Gegeben sei $y(x)=e^{-x/10}\sin(x)$. Betrachten Sie 10000 $x$-Intervalle im Bereich $[0,10]$.
#
# 1. Plotten Sie die Funktion $y(x)$ gegen $x$ im Bereich $[0,10]$.
# 2. Berechnen Sie den Mittelwert $\langle m\rangle$ von $y(x)$ für $x \in [4,7]$
#
#     (Zur Kontrolle: $\langle m\rangle\approx -0.2960$).
# 3. Plotten Sie $y(x)$ und $\frac{dy}{dx}$ gegen $x$ gemeinsam in einem Diagramm.
# 4. Bestimmen Sie die Stellen, an denen $\frac{dy}{dx}=0$ (Extremalstellen von $y(x)$). Sie dürfen annehmen, dass alle Nullstellen einfach sind.
#
#     **Hinweis:** An den Nullstellen findet zwischen benachbarten $y$-Werten ein Vorzeichenwechsel statt!
#
# **Hinweis:** Zur Berechnung der Ableitung verwenden Sie entweder Ihre Funktion des Aufgabenblatts zu Video 04 oder die Funktion `np.gradient`.

# %%
# Ihre Lösung hier bitte

# %% [markdown]
# ## Aufgabe 2
#
# Betrachten Sie die Blütenkurve $r(\theta)=1+\frac{3}{4}\sin(3\theta)$ für $\theta \in [0, 2\pi)$.
#
# 1. Erstellen Sie einen Plot der Blüte (bestimmen Sie dazu mit den Relationen $x=r\cos(\theta)$ und $y=r\sin(\theta)$ $x$- und $y$-Koordinatenpunkte).
#
# 2. Berechnen Sie numerisch den Flächeninhalt der Blüte mit der Formel
#    $$
#    A=\int_{0}^{2\pi}\frac{1}{2}r^2\,d\theta.
#    $$
#
#    (Zur Kontrolle das analytische Resultat: $A = \frac{41\pi}{32}\approx 4.0252$.)
#
# 3. Berechnen Sie numerisch die Bogenlänge der Blüte mit der Formel
#    $$
#    L=\int_{0}^{2\pi}\sqrt{r^2+\left(\frac{dr}{d\theta}\right)^2}\,d\theta.
#    $$
#
#    (Zur Kontrolle: $L\approx 12.426$. Das Integral ist nicht elementar analytisch lösbar.)
#
# **Hinweis:** Zur numerischen Integralberechnung verwenden Sie entweder das Verfahren aus dem Video oder die Funktion `np.trapzd`.

# %%
# Ihre Lösung hier bitte
