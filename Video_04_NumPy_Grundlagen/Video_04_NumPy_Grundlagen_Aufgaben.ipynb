# %% [markdown]
# # Aufgaben: Erster Kontakt mit NumPy-Arrays
#
# **Hinweise:** Vermeiden Sie in allen Aufgaben, mit Schleifen über Arrays zu iterieren, sondern nutzen Sie überall effiziente NumPy Vektor-Operationen und Slicing.

# %% [markdown]
# ### Aufgabe 1
# Erstellen Sie eine Python-Funktion, die $f(x) = \cos(x)\sin(x)$ berechnet, und plotten Sie die Funktion für $x \in [0, 1]$.
# (Hinweis: Erzeugen Sie ein NumPy-Array mit 1001 gleichmäßig verteilten $x$-Werten, werten Sie dann die Funktion aus und speichern die Ergebnisse in einem neuen Array, und plotten Sie diese anschließend.)

# %%
# Ihre Lösung hier

# %% [markdown]
# ### Aufgabe 2
# Eine Möglichkeit, das Integral einer Funktion numerisch zu berechnen, ist die Approximation (Riemann Summe) $\sum_i f(x_i)\Delta x$, wobei die Summe nur über die $x_i$ innerhalb der Integrationsgrenzen läuft.

# %% [markdown]
# - **Teil 1:** Verwenden Sie die Funktion `np.sum` und den Abstand zwischen den Werten im $x$-Array (also $\Delta x$) aus Frage 1, um
#   $$
#   I = \int_0^1 \cos(x)\sin(x)\,dx
#   $$
#   näherungsweise zu berechnen. Vergleichen Sie Ihr Ergebnis mit dem analytischen Resultat $I=\frac{1-\cos(2)}{4}$.
#
#   **Hinweis:** Die NumPy-Funktion zum Abschätzen numerischer Integrale lautet `np.trapz`. Diese können Sie zum Testen ihres Programms verwenden.

# %%
# Ihre Lösung hier

# %% [markdown]
# - **Teil 2:** Die NumPy-Funktion `np.cumsum(arr)` berechnet die kumulative Summe   der    Elemente in einem Array `arr`.
#   Zum Beispiel gilt: Wenn `arr = [0,4,7,2]`, dann ist `np.cumsum(arr) = [0,4,11,13]`.
#   Verwenden Sie diese Funktion, um
#   $$
#   F(x) = \int_0^x \cos(x')\sin(x')\,dx'
#   $$
#   zu berechnen und zu plotten. Vergleichen Sie mit der analytischen Stammfunktion $F(x)=\frac{1-\cos(2x)}{4}$.

# %%
# Ihre Lösung hier

# %% [markdown]
# ### Aufgabe 3
# Eine Möglichkeit, die Ableitung einer Funktion numerisch zu berechnen, ist die Näherung (Differenzformel) $ f'(x) \approx \frac{\Delta f(x)}{\Delta x} = \frac{f(x+\Delta x) - f(x)}{\Delta x}$.
#
# - **Teil 1:** Der Ausdruck `arr[1:] - arr[:-1]` kann verwendet werden, um mit einer Slicing Operation die Differenzen zwischen aufeinanderfolgenden Elementen eines Arrays zu berechnen.
#   Zum Beispiel gilt: Wenn `arr = [0,4,7,2]`, dann ist `arr[1:]-arr[:-1] = [4,3,-5]` (Hinweis: Die Länge des Arrays wird um 1 verkürzt!).
#   Verwenden Sie dies, um $\Delta f$ aus den Daten in Aufgabe 1 zu berechnen.

# %%
# Ihre Lösung hier

# %% [markdown]
# - **Teil 2:** Berechnen Sie $f' = \Delta f(x)/\Delta x$ und plotten Sie es als Funktion von $x$. Testen Sie Ihr Ergebnis mit der analytischen Ableitung $f'(x)=\cos(2x)$.
#
#   **Hinweise:** (1) Sie müssen sicherstellen, dass die $x$- und $y$-Arrays, die Sie plotten, die gleiche Länge haben. Überprüfen Sie die Längen, bevor Sie plotten; (2) Die NumPy-Funktion zum Abschätzen numerischer Ableitungen lautet `np.gradient`. Diese können Sie zum Testen ihres Programms verwenden.

# %%
# Ihre Lösung hier
